# %% [markdown]
# Ref: [Google Online Course](https://developers.google.cn/machine-learning/crash-course)
#
# 精确率：Precision = TP / ( TP + FP ), 在被识别为正类别的样本中，确实为正类别的比例是多少？
# 如果模型中没有**假正例**，则精确率为1.0
#
# 召回率：Recall = TP / ( TP + FN ) , 在所有正类别样本中，被正确识别为正类别的比例是多少？
# 如果模型中没有**假负例**，则召回率为1.0

# %% [markdown]
# 真正例率(同召回率）：TPR = TP / ( TP + FN )，在所有正类别样本中，被正确识别为正类别的比例是多少？
# 假正例率 ： FPR = FP ／（FP + TN）， 在所有负类别样本中，被错误识别为正类别的比例是多少？
#
# ROC ( 接受者操作特征曲线 ）：用于绘制采用不同分类阈值时的 TPR 与 FPR。降低分类阈值会导致将更多样本归为正类别，从而增加假正例和真正例的个数。
#
# ![image.png](attachment:image.png)

# %% [markdown]
# AUC(Area Under Curve)曲线下面积表示“ROC 曲线下面积”。也就是说，曲线下面积测量的是从 (0,0) 到 (1,1) 之间整个 ROC 曲线以下的整个二维面积（参考积分学）
